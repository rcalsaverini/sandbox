# %%
import sympy as sm
import sympy.physics.mechanics as smm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# m = smm.dynamicsymbols('m')
# md = smm.dynamicsymbols('m', 1)
# x   = smm.dynamicsymbols('x')
# xd  = smm.dynamicsymbols('x', 1)

# L = m * xd ** 2/2 + xd * md **2 / 2
# f_x = sm.diff(sm.diff(L, xd), 't') - sm.diff(L, x)
# f_m = sm.diff(sm.diff(L, md), 't') - sm.diff(L, m)

# %%
x = sm.Symbol("x")
d = sm.Symbol("d")

sm.solve(-4 * x/5 + d - (20 - 5 * x/4), x)
# Out:
# [400/9 - 20*d/9]

# %%
(- 5 * x/4).subs({x: (400 - 20 * d)/9})
# Out:
# 25*d/9 - 500/9

# %%
 400/9 - 20 * d/9
# Out:
# 44.4444444444444 - 20*d/9

# %%
20 - 25 * (20 - d)/9
# Out:
# 25*d/9 - 320/9
