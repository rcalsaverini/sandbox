# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.0.0rc1'

# %%
import io

data = io.StringIO("""a,b,c,d,e,f,g,h,i
    1,2.5,True,a,,,,,
    3,4.5,False,b,6,7.5,True,a,
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.convert_dtypes(dtype_backend="pyarrow")
#
# File ~/miniforge3/envs/pandas2/lib/python3.10/site-packages/pandas/core/generic.py:6671, in NDFrame.convert_dtypes(self, infer_objects, convert_string, convert_integer, convert_boolean, convert_floating, dtype_backend)
#    6662     return self._convert_dtypes(
#    6663         infer_objects,
#    6664         convert_string,
#    (...)
#    6668         dtype_backend=dtype_backend,
#    6669     )
#    6670 else:
# -> 6671     results = [
#    6672         col._convert_dtypes(
#    6673             infer_objects,
#    6674             convert_string,
#    6675             convert_integer,
#    6676             convert_boolean,
#    6677             convert_floating,
#    6678             dtype_backend=dtype_backend,
#    6679         )
# ...
