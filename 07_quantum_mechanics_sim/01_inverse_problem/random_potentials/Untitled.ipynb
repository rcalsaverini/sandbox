# %%
import numpy as np
from numpy import random as rnd
from matplotlib import pyplot as plt

# %%
from random_

# %%
x_space = np.linspace(x_lim[0], x_lim[1], num_spacial_bins)
k_space = np.arange(-num_fourier_bins // 2, num_fourier_bins // 2)
fourier_coeffs = rnd.normal(0, 1, num_fourier_bins) * np.exp(-k_space/num_fourier_bins)

# %%
cosines = np.cos(2 * np.pi * x_space[:, None] * k_space[None, :])
potential = cosines @ fourier_coeffs
potential - potential[0]

# %%
plt.plot(x_space, potential - potential[0])

# %%
plt.plot(x_space, )
